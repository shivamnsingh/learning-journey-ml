# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Teen_Mental_Health_Dataset.csv')

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                      low             2              2                1
# 1                     high             8              1               10
# 2                     high             2              4                2
# 3                   medium             1              7                9
# 4                   medium             3              5                2
#
#    depression_label
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df.shape
# Out:
# (1200, 13)

# %%
df.columns.tolist()
# Out:
# ['age',
#  'gender',
#  'daily_social_media_hours',
#  'platform_usage',
#  'sleep_hours',
#  'screen_time_before_sleep',
#  'academic_performance',
#  'physical_activity',
#  'social_interaction_level',
#  'stress_level',
#  'anxiety_level',
#  'addiction_level',
#  'depression_label']

# %%
df.dtypes
# Out:
# age                           int64
# gender                       object
# daily_social_media_hours    float64
# platform_usage               object
# sleep_hours                 float64
# screen_time_before_sleep    float64
# academic_performance        float64
# physical_activity           float64
# social_interaction_level     object
# stress_level                  int64
# anxiety_level                 int64
# addiction_level               int64
# depression_label              int64
# dtype: object

# %%
df.isna().sum()
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64

# %%
df.describe()
# Out:
#                age  daily_social_media_hours  sleep_hours  \
# count  1200.000000               1200.000000  1200.000000
# mean     15.928333                  4.536667     6.449417
# std       2.021947                  2.029599     1.442677
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.300000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1200.000000           1200.000000        1200.000000
# mean                   1.740333              2.990383           1.014500
# std                    0.716660              0.576758           0.582185
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# 50%                    1.800000              2.990000           1.000000
# 75%                    2.400000              3.480000           1.500000
# max                    3.000000              4.000000           2.000000
#
#        stress_level  anxiety_level  addiction_level  depression_label
# count   1200.000000    1200.000000      1200.000000       1200.000000
# mean       5.445833       5.636667         5.565000          0.025833
# std        2.903290       2.859453         2.830627          0.158704
# min        1.000000       1.000000         1.000000          0.000000
# 25%        3.000000       3.000000         3.000000          0.000000
# 50%        5.000000       6.000000         6.000000          0.000000
# 75%        8.000000       8.000000         8.000000          0.000000
# max       10.000000      10.000000        10.000000          1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(include=np.number).columns

# %%
for cols in cat_cols:
    print(f"Value counts for {cols}:\n{df[cols].value_counts()}\n")
# Out:
# Value counts for gender:
# gender
# male      615
# female    585
# Name: count, dtype: int64
#
# Value counts for platform_usage:
# platform_usage
# Instagram    411
# TikTok       398
# Both         391
# Name: count, dtype: int64
#
# Value counts for social_interaction_level:
# social_interaction_level
# medium    416
# low       415
# high      369
# Name: count, dtype: int64

# %%
for cols in cat_cols:
    print(f"Value count for {cols} is {df[cols].value_counts()}\n")
# Out:
# Value count for gender is gender
# male      615
# female    585
# Name: count, dtype: int64
#
# Value count for platform_usage is platform_usage
# Instagram    411
# TikTok       398
# Both         391
# Name: count, dtype: int64
#
# Value count for social_interaction_level is social_interaction_level
# medium    416
# low       415
# high      369
# Name: count, dtype: int64

# %%
df[num_cols].hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.savefig("distributions.png")
plt.show()
